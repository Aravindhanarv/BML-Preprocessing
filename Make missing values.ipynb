# %%
import pandas as pd
import numpy as np
import random

# %%
data=pd.read_csv('TCS.csv')
data
# Out:
#            Date Symbol Series  Prev Close     Open     High      Low     Last  \
# 0    01-01-2018    TCS     EQ     2701.20  2682.30  2694.80  2635.00  2650.00
# 1    02-01-2018    TCS     EQ     2645.60  2660.00  2669.60  2620.20  2631.00
# 2    03-01-2018    TCS     EQ     2631.20  2632.00  2669.00  2631.20  2639.00
# 3    04-01-2018    TCS     EQ     2638.65  2650.00  2662.00  2640.00  2650.00
# 4    05-01-2018    TCS     EQ     2657.10  2650.00  2699.50  2650.00  2695.00
# ..          ...    ...    ...         ...      ...      ...      ...      ...
# 818  26-04-2021    TCS     EQ     3109.50  3102.05  3153.00  3088.05  3100.05
# 819  27-04-2021    TCS     EQ     3100.80  3106.00  3136.10  3103.00  3132.75
# 820  28-04-2021    TCS     EQ     3132.00  3149.95  3151.00  3112.00  3123.00
# 821  29-04-2021    TCS     EQ     3124.10  3145.60  3157.35  3105.50  3114.45
# 822  30-04-2021    TCS     EQ     3115.25  3099.00  3132.05  3020.00  3040.00
#
# ...

# %%
data.drop("Series",axis=1,inplace=True)

# %%
data.shape[0]
# Out:
# 823

# %%
for col in data.columns:
    data.loc[data.sample(frac=0.1).index, col] = np.nan

# %%
data
# Out:
#            Date Symbol  Prev Close     Open     High      Low     Last  \
# 0    01-01-2018    TCS     2701.20  2682.30  2694.80  2635.00  2650.00
# 1    02-01-2018    TCS     2645.60  2660.00  2669.60  2620.20      NaN
# 2    03-01-2018    NaN     2631.20  2632.00      NaN  2631.20  2639.00
# 3    04-01-2018    TCS     2638.65  2650.00  2662.00  2640.00  2650.00
# 4    05-01-2018    TCS         NaN  2650.00  2699.50  2650.00  2695.00
# ..          ...    ...         ...      ...      ...      ...      ...
# 818  26-04-2021    TCS     3109.50  3102.05  3153.00  3088.05  3100.05
# 819  27-04-2021    TCS     3100.80  3106.00  3136.10  3103.00  3132.75
# 820  28-04-2021    TCS     3132.00  3149.95  3151.00  3112.00      NaN
# 821  29-04-2021    TCS     3124.10  3145.60      NaN  3105.50  3114.45
# 822  30-04-2021    TCS     3115.25  3099.00  3132.05  3020.00  3040.00
#
#        Close     VWAP     Volume      Turnover    Trades  Deliverable Volume  \
# ...

# %%
data['Symbol'].fillna(value="TCS",inplace=True)

# %%
data
# Out:
#            Date Symbol  Prev Close     Open     High      Low     Last  \
# 0    01-01-2018    TCS     2701.20  2682.30  2694.80  2635.00  2650.00
# 1    02-01-2018    TCS     2645.60  2660.00  2669.60  2620.20      NaN
# 2    03-01-2018    TCS     2631.20  2632.00      NaN  2631.20  2639.00
# 3    04-01-2018    TCS     2638.65  2650.00  2662.00  2640.00  2650.00
# 4    05-01-2018    TCS         NaN  2650.00  2699.50  2650.00  2695.00
# ..          ...    ...         ...      ...      ...      ...      ...
# 818  26-04-2021    TCS     3109.50  3102.05  3153.00  3088.05  3100.05
# 819  27-04-2021    TCS     3100.80  3106.00  3136.10  3103.00  3132.75
# 820  28-04-2021    TCS     3132.00  3149.95  3151.00  3112.00      NaN
# 821  29-04-2021    TCS     3124.10  3145.60      NaN  3105.50  3114.45
# 822  30-04-2021    TCS     3115.25  3099.00  3132.05  3020.00  3040.00
#
#        Close     VWAP     Volume      Turnover    Trades  Deliverable Volume  \
# ...

# %%
compression_opts = dict(method='zip',archive_name='Stock_Market.csv')  
data.to_csv('Stock_Market.zip', index=False,compression=compression_opts)
